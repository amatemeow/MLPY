# %%
import numpy as np
import pandas as pd
import mlxtend.frequent_patterns as ml

# %%
lastfm = pd.read_csv('lastfm.csv')
countries = ['Germany', 'United States', 'Russian Federation', 'Finland', 'United Kingdom']
lastfm = lastfm[lastfm['country'].isin(countries)]

lastfm
# Out:
#          user                   artist sex         country
# 0           1    red hot chili peppers   f         Germany
# 1           1  the black dahlia murder   f         Germany
# 2           1                goldfrapp   f         Germany
# 3           1         dropkick murphys   f         Germany
# 4           1                 le tigre   f         Germany
# ...       ...                      ...  ..             ...
# 289904  19715              david bowie   m  United Kingdom
# 289905  19715               ben harper   m  United Kingdom
# 289906  19715               lily allen   m  United Kingdom
# 289907  19715              andrew bird   m  United Kingdom
# 289908  19715                  madonna   m  United Kingdom
#
# [133280 rows x 4 columns]

# %% [markdown]
# <h3></h3>

# %%
grouped = lastfm.groupby('user')['artist'].apply(';'.join)

grouped
# Out:
# user
# 1        red hot chili peppers;the black dahlia murder;...
# 3        devendra banhart;boards of canada;cocorosie;ap...
# 4        tv on the radio;tool;kyuss;dj shadow;air;a tri...
# 5        dream theater;ac/dc;metallica;iron maiden;bob ...
# 7        soundgarden;stone temple pilots;buckethead;dre...
#                                ...
# 19706            enigma;pink floyd;the offspring;scorpions
# 19709    oasis;foo fighters;kings of leon;taylor swift;...
# 19710    vnv nation;nine inch nails;kmfdm;apoptygma ber...
# 19714    misfits;type o negative;arch enemy;red hot chi...
# 19715    abba;james blunt;jason mraz;amy winehouse;quee...
# Name: artist, Length: 6713, dtype: object

# %%
grouped_bin = grouped.str.get_dummies(";")
grouped_bin.iloc[0:10, 100:110]
# Out:
#       beastie boys  beatsteaks  beck  bee gees  behemoth  beirut  \
# user
# 1                0           0     0         0         0       0
# 3                1           0     0         0         0       0
# 4                0           0     1         0         0       0
# 5                0           0     0         0         0       0
# 7                0           0     0         0         0       0
# 9                0           0     0         0         0       0
# 18               0           0     0         0         0       0
# 20               0           0     1         0         0       1
# 22               0           0     0         0         0       0
# 24               0           0     0         0         0       0
#
#       belle and sebastian  ben folds  ben folds five  ben harper
# user
# 1                       0          0               0           0
# 3                       0          0               0           0
# 4                       0          0               0           0
# 5                       0          0               0           0
# 7                       0          0               0           0
# 9                       0          0               0           0
# 18                      0          0               0           0
# 20                      0          0               0           0
# 22                      0          0               0           0
# 24                      0          0               0           0

# %% [markdown]
# <h3>Обработка выборки мужчин</h3>

# %%
grouped_male = lastfm[lastfm['sex'] == 'm'].groupby('user')['artist'].apply(';'.join)
grouped_male_bin = grouped_male.str.get_dummies(";")

grouped_male
# Out:
# user
# 3        devendra banhart;boards of canada;cocorosie;ap...
# 4        tv on the radio;tool;kyuss;dj shadow;air;a tri...
# 5        dream theater;ac/dc;metallica;iron maiden;bob ...
# 7        soundgarden;stone temple pilots;buckethead;dre...
# 9        arch enemy;strapping young lad;kreator;childre...
#                                ...
# 19702    muse;finch;regina spektor;radiohead;rage again...
# 19705    muse;neutral milk hotel;animal collective;mode...
# 19709    oasis;foo fighters;kings of leon;taylor swift;...
# 19714    misfits;type o negative;arch enemy;red hot chi...
# 19715    abba;james blunt;jason mraz;amy winehouse;quee...
# Name: artist, Length: 4973, dtype: object

# %% [markdown]
# <h3>Обработка выборки женщин</h3>

# %%
grouped_female = lastfm[lastfm['sex'] == 'f'].groupby('user')['artist'].apply(';'.join)
grouped_female_bin = grouped_female.str.get_dummies(";")

grouped_female
# Out:
# user
# 1        red hot chili peppers;the black dahlia murder;...
# 20       of montreal;the magnetic fields;devo;talking h...
# 32       nick cave and the bad seeds;black flag;the gos...
# 33       death cab for cutie;tegan and sara;kimya dawso...
# 42       soundtrack;groove coverage;avril lavigne;the r...
#                                ...
# 19691    nine inch nails;the smashing pumpkins;mindless...
# 19695    the kills;bright eyes;adam green;cocorosie;dev...
# 19701    placebo;animal collective;crystal castles;brok...
# 19706            enigma;pink floyd;the offspring;scorpions
# 19710    vnv nation;nine inch nails;kmfdm;apoptygma ber...
# Name: artist, Length: 1740, dtype: object

# %% [markdown]
# <h3>Обработка выборки пользователей из России</h3>

# %%
grouped_ru = lastfm[lastfm['country'] == 'Russian Federation'].groupby('user')['artist'].apply(';'.join)
grouped_ru_bin = grouped_ru.str.get_dummies(";")

grouped_ru
# Out:
# user
# 39       britney spears;a-ha;joss stone;christina aguil...
# 50       the ataris;yann tiersen;the smashing pumpkins;...
# 82       p.o.d.;chimaira;arch enemy;scar symmetry;slipk...
# 84       queen;radiohead;the beatles;louis armstrong;el...
# 167      koЯn;slipknot;soulfly;static-x;linkin park;ill...
#                                ...
# 19656    queen;arctic monkeys;nofx;placebo;ac/dc;the ko...
# 19671    unkle;lynyrd skynyrd;apparat;the beatles;pet s...
# 19702    muse;finch;regina spektor;radiohead;rage again...
# 19706            enigma;pink floyd;the offspring;scorpions
# 19710    vnv nation;nine inch nails;kmfdm;apoptygma ber...
# Name: artist, Length: 785, dtype: object

# %% [markdown]
# <h3>Обработка выборки пользователей из Великобритании</h3>

# %%
grouped_uk = lastfm[lastfm['country'] == 'United Kingdom'].groupby('user')['artist'].apply(';'.join)
grouped_uk_bin = grouped_uk.str.get_dummies(";")

grouped_uk
# Out:
# user
# 4        tv on the radio;tool;kyuss;dj shadow;air;a tri...
# 22       the jam;maxïmo park;supergrass;simon & garfunk...
# 24       the byrds;leonard cohen;the beatles;simon & ga...
# 43       the knife;of montreal;john mayer;nada surf;fle...
# 66       loreena mckennitt;garbage;joni mitchell;amy ma...
#                                ...
# 19689    shpongle;air;linkin park;infected mushroom;pen...
# 19705    muse;neutral milk hotel;animal collective;mode...
# 19709    oasis;foo fighters;kings of leon;taylor swift;...
# 19714    misfits;type o negative;arch enemy;red hot chi...
# 19715    abba;james blunt;jason mraz;amy winehouse;quee...
# Name: artist, Length: 1256, dtype: object

# %% [markdown]
# <h3>Обработка выборки пользователей из США</h3>

# %%
grouped_us = lastfm[lastfm['country'] == 'United States'].groupby('user')['artist'].apply(';'.join)
grouped_us_bin = grouped_us.str.get_dummies(";")

grouped_us
# Out:
# user
# 3        devendra banhart;boards of canada;cocorosie;ap...
# 9        arch enemy;strapping young lad;kreator;childre...
# 18       sonata arctica;infected mushroom;iron maiden;c...
# 20       of montreal;the magnetic fields;devo;talking h...
# 32       nick cave and the bad seeds;black flag;the gos...
#                                ...
# 19674    soundtrack;fiona apple;jason mraz;sara bareill...
# 19676    stevie wonder;the beatles;erykah badu;the smit...
# 19682    the beatles;rihanna;good charlotte;aerosmith;e...
# 19691    nine inch nails;the smashing pumpkins;mindless...
# 19701    placebo;animal collective;crystal castles;brok...
# Name: artist, Length: 2905, dtype: object

# %% [markdown]
# <h3>Обработка выборки пользователей из Финляндии</h3>

# %%
grouped_fi = lastfm[lastfm['country'] == 'Finland'].groupby('user')['artist'].apply(';'.join)
grouped_fi_bin = grouped_fi.str.get_dummies(";")

grouped_fi
# Out:
# user
# 5        dream theater;ac/dc;metallica;iron maiden;bob ...
# 7        soundgarden;stone temple pilots;buckethead;dre...
# 58       john frusciante;morrissey;against me!;in flame...
# 63       ministry;turbonegro;paradise lost;katatonia;pj...
# 269      lagwagon;the distillers;ska-p;misfits;avril la...
#                                ...
# 19234    akon;t.i.;kanye west;foo fighters;eminem;lupe ...
# 19346    pink floyd;tool;led zeppelin;rush;porcupine tr...
# 19362    sentenced;in flames;dark tranquillity;volbeat;...
# 19485    rancid;red hot chili peppers;bad religion;chil...
# 19506    the beatles;moby;coldplay;jamiroquai;red hot c...
# Name: artist, Length: 510, dtype: object

# %% [markdown]
# <h3>Обработка выборки пользователей из Германии</h3>

# %%
grouped_de = lastfm[lastfm['country'] == 'Germany'].groupby('user')['artist'].apply(';'.join)
grouped_de_bin = grouped_de.str.get_dummies(";")

grouped_de
# Out:
# user
# 1        red hot chili peppers;the black dahlia murder;...
# 33       death cab for cutie;tegan and sara;kimya dawso...
# 42       soundtrack;groove coverage;avril lavigne;the r...
# 51       kate nash;arctic monkeys;lykke li;adele;tegan ...
# 62       beatsteaks;clueso;the kooks;die Ärzte;plain wh...
#                                ...
# 19639    aerosmith;lenny kravitz;adam green;the hellaco...
# 19642    fear factory;hypocrisy;the velvet underground;...
# 19662    blind guardian;in extremo;subway to sally;finn...
# 19672    system of a down;björk;portishead;the prodigy;...
# 19695    the kills;bright eyes;adam green;cocorosie;dev...
# Name: artist, Length: 1257, dtype: object

# %% [markdown]
# <h1>Алгоритм Apriori</h1>

# %% [markdown]
# <h3>Характерные комбинации для общей выборки из 5 стран</h3>

# %%
freq_items = ml.apriori(grouped_bin, min_support = 0.035, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_items))
print(freq_items)
print("Максимальная длина набора: %d" % freq_items['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 143 характерных комбинаций
#       support                              itemsets
# 0    0.052138                               (ac/dc)
# 1    0.037390                                 (afi)
# 2    0.065098                                 (air)
# 3    0.047520                       (amy winehouse)
# 4    0.046775                   (animal collective)
# ..        ...                                   ...
# 138  0.036645                     (radiohead, muse)
# 139  0.040072             (the beatles, pink floyd)
# 140  0.036347                (radiohead, sigur rós)
# 141  0.068226              (radiohead, the beatles)
# 142  0.035007  (red hot chili peppers, the beatles)
#
# [143 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_items = ml.association_rules(freq_items, metric = "confidence", min_threshold = 0.35)
rules_items
# Out:
#              antecedents    consequents  antecedent support  \
# 0                 (beck)    (radiohead)            0.073589
# 1            (bob dylan)  (the beatles)            0.074035
# 2          (the killers)     (coldplay)            0.097423
# 3          (david bowie)  (the beatles)            0.082526
# 4  (death cab for cutie)    (radiohead)            0.107255
# 5         (led zeppelin)  (the beatles)            0.077909
# 6           (pink floyd)  (the beatles)            0.092954
# 7            (sigur rós)    (radiohead)            0.069269
# 8            (radiohead)  (the beatles)            0.183376
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.183376  0.037688    0.512146  2.792879  0.024194    1.673911
# 1            0.201549  0.039327    0.531187  2.635520  0.024405    1.703133
# 2            0.144496  0.037241    0.382263  2.645496  0.023164    1.384900
# 3            0.201549  0.037986    0.460289  2.283754  0.021353    1.479404
# 4            0.183376  0.040369    0.376389  2.052558  0.020702    1.309509
# 5            0.201549  0.035454    0.455067  2.257845  0.019751    1.465227
# 6            0.201549  0.040072    0.431090  2.138881  0.021337    1.403474
# 7            0.183376  0.036347    0.524731  2.861511  0.023645    1.718237
# 8            0.201549  0.068226    0.372055  1.845977  0.031267    1.271530

# %% [markdown]
# <h3>Характерные комбинации для выборки мужчин</h3>

# %%
freq_male = ml.apriori(grouped_male_bin, min_support = 0.035, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_male))
print(freq_male)
print("Максимальная длина набора: %d" % freq_male['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 130 характерных комбинаций
#       support                           itemsets
# 0    0.059924                            (ac/dc)
# 1    0.062136                              (air)
# 2    0.044440                (animal collective)
# 3    0.050271                       (aphex twin)
# 4    0.051880                      (arcade fire)
# ..        ...                                ...
# 125  0.035793                  (radiohead, muse)
# 126  0.043032          (the beatles, pink floyd)
# 127  0.036195             (radiohead, sigur rós)
# 128  0.066962           (radiohead, the beatles)
# 129  0.035793  (the beatles, the rolling stones)
#
# [130 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_male = ml.association_rules(freq_male, metric = "confidence", min_threshold = 0.35)
rules_male
# Out:
#             antecedents    consequents  antecedent support  \
# 0                (beck)    (radiohead)            0.070179
# 1           (bob dylan)  (the beatles)            0.075608
# 2            (coldplay)    (radiohead)            0.124472
# 3         (david bowie)  (the beatles)            0.078625
# 4        (led zeppelin)  (the beatles)            0.084054
# 5                (muse)    (radiohead)            0.097326
# 6          (pink floyd)  (the beatles)            0.104162
# 7           (sigur rós)    (radiohead)            0.067163
# 8           (radiohead)  (the beatles)            0.183994
# 9  (the rolling stones)  (the beatles)            0.073195
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.183994  0.035994    0.512894  2.787565  0.023082    1.675213
# 1            0.192841  0.040217    0.531915  2.758303  0.025637    1.724384
# 2            0.183994  0.045445    0.365105  1.984336  0.022543    1.285262
# 3            0.192841  0.037201    0.473146  2.453549  0.022039    1.532034
# 4            0.192841  0.037603    0.447368  2.319878  0.021394    1.460573
# 5            0.183994  0.035793    0.367769  1.998812  0.017886    1.290677
# 6            0.192841  0.043032    0.413127  2.142318  0.022946    1.375356
# 7            0.183994  0.036195    0.538922  2.929027  0.023838    1.769780
# 8            0.192841  0.066962    0.363934  1.887222  0.031480    1.268987
# 9            0.192841  0.035793    0.489011  2.535820  0.021678    1.579601

# %% [markdown]
# <h3>Характерные комбинации для выборки женщин</h3>

# %%
freq_female = ml.apriori(grouped_female_bin, min_support = 0.035, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_female))
print(freq_female)
print("Максимальная длина набора: %d" % freq_female['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 106 характерных комбинаций
#       support                            itemsets
# 0    0.073563                               (air)
# 1    0.088506                     (amy winehouse)
# 2    0.053448                 (animal collective)
# 3    0.065517                       (arcade fire)
# 4    0.082184                    (arctic monkeys)
# ..        ...                                 ...
# 101  0.063218  (the beatles, death cab for cutie)
# 102  0.062069    (the shins, death cab for cutie)
# 103  0.071839            (radiohead, the beatles)
# 104  0.054598              (radiohead, the shins)
# 105  0.050000            (the beatles, the shins)
#
# [106 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_female = ml.association_rules(freq_female, metric = "confidence", min_threshold = 0.35)
rules_female
# Out:
#              antecedents            consequents  antecedent support  \
# 0  (death cab for cutie)             (coldplay)            0.170690
# 1          (the killers)             (coldplay)            0.128736
# 2  (death cab for cutie)          (the beatles)            0.170690
# 3            (the shins)  (death cab for cutie)            0.118391
# 4  (death cab for cutie)            (the shins)            0.170690
# 5            (radiohead)          (the beatles)            0.181609
# 6            (the shins)            (radiohead)            0.118391
# 7            (the shins)          (the beatles)            0.118391
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.201724  0.064943    0.380471  1.886097  0.030510    1.288521
# 1            0.201724  0.057471    0.446429  2.213065  0.031502    1.442047
# 2            0.226437  0.063218    0.370370  1.635646  0.024568    1.228600
# 3            0.170690  0.062069    0.524272  3.071492  0.041861    1.743244
# 4            0.118391  0.062069    0.363636  3.071492  0.041861    1.385386
# 5            0.226437  0.071839    0.395570  1.746932  0.030716    1.279822
# 6            0.181609  0.054598    0.461165  2.539327  0.033097    1.518815
# 7            0.226437  0.050000    0.422330  1.865113  0.023192    1.339109

# %% [markdown]
# <h3>Характерные комбинации для выборки пользователей из России</h3>

# %%
freq_ru = ml.apriori(grouped_ru_bin, min_support = 0.03, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_ru))
print(freq_ru)
print("Максимальная длина набора: %d" % freq_ru['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 134 характерных комбинаций
#       support                  itemsets
# 0    0.056051      (30 seconds to mars)
# 1    0.030573          (65daysofstatic)
# 2    0.040764               ([unknown])
# 3    0.040764                    (a-ha)
# 4    0.042038                   (ac/dc)
# ..        ...                       ...
# 129  0.036943       (the killers, muse)
# 130  0.034395        (placebo, nirvana)
# 131  0.038217      (radiohead, placebo)
# 132  0.040764    (the killers, placebo)
# 133  0.030573  (radiohead, the beatles)
#
# [134 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_ru = ml.association_rules(freq_ru, metric = "confidence", min_threshold = 0.3)
rules_ru
# Out:
#                 antecedents    consequents  antecedent support  \
# 0                (coldplay)         (muse)            0.095541
# 1                (coldplay)      (placebo)            0.095541
# 2                (coldplay)    (radiohead)            0.095541
# 3             (the killers)     (coldplay)            0.085350
# 4                (coldplay)  (the killers)            0.095541
# 5             (linkin park)  (the prodigy)            0.113376
# 6               (metallica)      (nirvana)            0.100637
# 7                    (muse)      (placebo)            0.124841
# 8                 (placebo)         (muse)            0.132484
# 9               (radiohead)         (muse)            0.128662
# 10                   (muse)    (radiohead)            0.124841
# 11  (red hot chili peppers)         (muse)            0.098089
# 12            (the killers)         (muse)            0.085350
# 13            (the killers)      (placebo)            0.085350
# 14                (placebo)  (the killers)            0.132484
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.124841  0.036943    0.386667  3.097279  0.025015    1.426890
# 1             0.132484  0.035669    0.373333  2.817949  0.023011    1.384334
# 2             0.128662  0.035669    0.373333  2.901650  0.023376    1.390432
# 3             0.095541  0.031847    0.373134  3.905473  0.023693    1.442827
# 4             0.085350  0.031847    0.333333  3.905473  0.023693    1.371975
# 5             0.132484  0.034395    0.303371  2.289866  0.019374    1.245305
# 6             0.118471  0.034395    0.341772  2.884851  0.022472    1.339245
# 7             0.132484  0.053503    0.428571  3.234890  0.036964    1.518153
# 8             0.124841  0.053503    0.403846  3.234890  0.036964    1.468009
# 9             0.124841  0.042038    0.326733  2.617195  0.025976    1.299869
# 10            0.128662  0.042038    0.336735  2.617195  0.025976    1.313709
# 11            0.124841  0.031847    0.324675  2.600716  0.019602    1.295909
# 12            0.124841  0.036943    0.432836  3.467103  0.026287    1.543044
# 13            0.132484  0.040764    0.477612  3.605052  0.029457    1.660673
# 14            0.085350  0.040764    0.307692  3.605052  0.029457    1.321161

# %% [markdown]
# <h3>Характерные комбинации для выборки пользователей из Великобритании</h3>

# %%
freq_uk = ml.apriori(grouped_uk_bin, min_support = 0.035, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_uk))
print(freq_uk)
print("Максимальная длина набора: %d" % freq_uk['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 115 характерных комбинаций
#       support                    itemsets
# 0    0.087580                       (air)
# 1    0.074045             (amy winehouse)
# 2    0.062102                (aphex twin)
# 3    0.086783               (arcade fire)
# 4    0.119427            (arctic monkeys)
# ..        ...                         ...
# 110  0.056529  (radiohead, kings of leon)
# 111  0.060510           (radiohead, muse)
# 112  0.050159         (muse, the beatles)
# 113  0.082803    (radiohead, the beatles)
# 114  0.052548     (radiohead, the smiths)
#
# [115 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_uk = ml.association_rules(freq_uk, metric = "confidence", min_threshold = 0.35)
rules_uk
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 0   (kings of leon)     (bloc party)            0.149682            0.136146
# 1      (bloc party)  (kings of leon)            0.136146            0.149682
# 2      (bloc party)      (radiohead)            0.136146            0.231688
# 3            (blur)      (radiohead)            0.101115            0.231688
# 4        (coldplay)      (radiohead)            0.149682            0.231688
# 5        (coldplay)    (snow patrol)            0.149682            0.103503
# 6     (snow patrol)       (coldplay)            0.103503            0.149682
# 7        (coldplay)    (the beatles)            0.149682            0.214968
# 8     (the killers)       (coldplay)            0.132166            0.149682
# 9     (david bowie)    (the beatles)            0.153662            0.214968
# 10  (kings of leon)      (radiohead)            0.149682            0.231688
# 11           (muse)      (radiohead)            0.166401            0.231688
# 12      (radiohead)    (the beatles)            0.231688            0.214968
# 13    (the beatles)      (radiohead)            0.214968            0.231688
# 14     (the smiths)      (radiohead)            0.118631            0.231688
#
#      support  confidence      lift  leverage  conviction
# 0   0.054936    0.367021  2.695782  0.034558    1.364743
# 1   0.054936    0.403509  2.695782  0.034558    1.425534
# 2   0.052548    0.385965  1.665883  0.021004    1.251251
# 3   0.055732    0.551181  2.378981  0.032305    1.711853
# 4   0.061306    0.409574  1.767785  0.026626    1.301285
# 5   0.056529    0.377660  3.648773  0.041036    1.440525
# 6   0.056529    0.546154  3.648773  0.041036    1.873583
# 7   0.053344    0.356383  1.657841  0.021167    1.219719
# 8   0.050955    0.385542  2.575750  0.031173    1.383852
# 9   0.067675    0.440415  2.048743  0.034643    1.402881
# 10  0.056529    0.377660  1.630036  0.021849    1.234553
# 11  0.060510    0.363636  1.569510  0.021956    1.207348
# 12  0.082803    0.357388  1.662518  0.032997    1.221627
# 13  0.082803    0.385185  1.662518  0.032997    1.249664
# 14  0.052548    0.442953  1.911852  0.025063    1.379259

# %% [markdown]
# <h3>Характерные комбинации для выборки пользователей из США</h3>

# %%
freq_us = ml.apriori(grouped_us_bin, min_support = 0.04, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_us))
print(freq_us)
print("Максимальная длина набора: %d" % freq_us['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 106 характерных комбинаций
#       support                     itemsets
# 0    0.058176                        (air)
# 1    0.059552                (andrew bird)
# 2    0.079862          (animal collective)
# 3    0.074010                (arcade fire)
# 4    0.067126               (beastie boys)
# ..        ...                          ...
# 101  0.052668    (the beatles, pink floyd)
# 102  0.056454  (radiohead, sufjan stevens)
# 103  0.100172     (radiohead, the beatles)
# 104  0.058520       (radiohead, the shins)
# 105  0.055766     (the beatles, the shins)
#
# [106 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_us = ml.association_rules(freq_us, metric = "confidence", min_threshold = 0.4)
rules_us
# Out:
#               antecedents            consequents  antecedent support  \
# 0                  (beck)            (radiohead)            0.109811
# 1                  (beck)          (the beatles)            0.109811
# 2             (bob dylan)          (the beatles)            0.104647
# 3              (coldplay)  (death cab for cutie)            0.153873
# 4   (death cab for cutie)             (coldplay)            0.176592
# 5              (coldplay)            (radiohead)            0.153873
# 6              (coldplay)          (the beatles)            0.153873
# 7          (modest mouse)  (death cab for cutie)            0.142513
# 8   (death cab for cutie)            (radiohead)            0.176592
# 9   (death cab for cutie)          (the beatles)            0.176592
# 10            (the shins)  (death cab for cutie)            0.124957
# 11         (led zeppelin)          (the beatles)            0.107401
# 12         (modest mouse)            (radiohead)            0.142513
# 13         (modest mouse)          (the beatles)            0.142513
# 14           (pink floyd)          (the beatles)            0.110843
# 15       (sufjan stevens)            (radiohead)            0.113597
# 16            (radiohead)          (the beatles)            0.230981
# 17          (the beatles)            (radiohead)            0.270568
# 18            (the shins)            (radiohead)            0.124957
# 19            (the shins)          (the beatles)            0.124957
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.230981  0.061962    0.564263  2.442899  0.036598    1.764871
# 1             0.270568  0.055077    0.501567  1.853757  0.025366    1.463452
# 2             0.270568  0.058864    0.562500  2.078960  0.030550    1.667273
# 3             0.176592  0.063339    0.411633  2.330983  0.036166    1.399480
# 4             0.153873  0.063339    0.358674  2.330983  0.036166    1.319341
# 5             0.230981  0.058520    0.380313  1.646512  0.022978    1.240980
# 6             0.270568  0.056110    0.364653  1.347732  0.014477    1.148085
# 7             0.176592  0.052324    0.367150  2.079084  0.027157    1.301110
# 8             0.230981  0.067126    0.380117  1.645663  0.026336    1.240587
# 9             0.270568  0.068158    0.385965  1.426499  0.020378    1.187932
# 10            0.176592  0.059552    0.476584  2.698785  0.037486    1.573142
# 11            0.270568  0.054389    0.506410  1.871656  0.025330    1.477810
# 12            0.230981  0.060241    0.422705  1.830043  0.027323    1.332108
# 13            0.270568  0.057487    0.403382  1.490870  0.018928    1.222611
# 14            0.270568  0.052668    0.475155  1.756140  0.022677    1.389805
# 15            0.230981  0.056454    0.496970  2.151560  0.030216    1.528773
# 16            0.270568  0.100172    0.433681  1.602854  0.037676    1.288023
# 17            0.230981  0.100172    0.370229  1.602854  0.037676    1.221109
# 18            0.230981  0.058520    0.468320  2.027524  0.029657    1.446393
# 19            0.270568  0.055766    0.446281  1.649423  0.021957    1.317332

# %% [markdown]
# <h3>Характерные комбинации для выборки пользователей из Финляндии</h3>

# %%
freq_fi = ml.apriori(grouped_fi_bin, min_support = 0.05, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_fi))
print(freq_fi)
print("Максимальная длина набора: %d" % freq_fi['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 118 характерных комбинаций
#       support                       itemsets
# 0    0.050980                      (50 cent)
# 1    0.103922                        (ac/dc)
# 2    0.056863                          (air)
# 3    0.060784                         (akon)
# 4    0.111765                     (amorphis)
# ..        ...                            ...
# 113  0.050980         (rammstein, metallica)
# 114  0.050980    (sonata arctica, metallica)
# 115  0.066667  (metallica, system of a down)
# 116  0.072549    (sonata arctica, nightwish)
# 117  0.058824  (system of a down, nightwish)
#
# [118 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_fi = ml.association_rules(freq_fi, metric = "confidence", min_threshold = 0.5)
rules_fi
# Out:
#             antecedents          consequents  antecedent support  \
# 0            (amorphis)          (in flames)            0.111765
# 1   (children of bodom)          (in flames)            0.133333
# 2   (children of bodom)          (metallica)            0.133333
# 3   (children of bodom)          (nightwish)            0.133333
# 4           (sentenced)  (children of bodom)            0.096078
# 5   (dark tranquillity)          (in flames)            0.068627
# 6            (soilwork)          (in flames)            0.096078
# 7      (sonata arctica)          (in flames)            0.125490
# 8         (iron maiden)          (metallica)            0.119608
# 9                (koЯn)   (system of a down)            0.098039
# 10     (sonata arctica)          (nightwish)            0.125490
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.209804  0.060784    0.543860  2.592228  0.037336    1.732353
# 1             0.209804  0.076471    0.573529  2.733645  0.048497    1.852874
# 2             0.215686  0.068627    0.514706  2.386364  0.039869    1.616162
# 3             0.215686  0.070588    0.529412  2.454545  0.041830    1.666667
# 4             0.133333  0.050980    0.530612  3.979592  0.038170    1.846377
# 5             0.209804  0.050980    0.742857  3.540721  0.036582    3.072985
# 6             0.209804  0.064706    0.673469  3.209994  0.044548    2.419975
# 7             0.209804  0.064706    0.515625  2.457652  0.038378    1.631373
# 8             0.215686  0.062745    0.524590  2.432191  0.036947    1.649763
# 9             0.184314  0.056863    0.580000  3.146809  0.038793    1.942110
# 10            0.215686  0.072549    0.578125  2.680398  0.045483    1.859114

# %% [markdown]
# <h3>Характерные комбинации для выборки пользователей из Германии</h3>

# %%
freq_de = ml.apriori(grouped_de_bin, min_support = 0.035, use_colnames = True)
print("Найдено %d характерных комбинаций" % len(freq_de))
print(freq_de)
print("Максимальная длина набора: %d" % freq_de['itemsets'].apply(lambda x: len(x)).max())
# Out:
# Найдено 170 характерных комбинаций
#       support                                   itemsets
# 0    0.065235                             (3 doors down)
# 1    0.050119                       (30 seconds to mars)
# 2    0.065235                                ([unknown])
# 3    0.070804                                    (ac/dc)
# 4    0.076372                                      (air)
# ..        ...                                        ...
# 165  0.035004              (metallica, system of a down)
# 166  0.035800           (red hot chili peppers, nirvana)
# 167  0.035800               (rammstein, subway to sally)
# 168  0.053302              (rammstein, system of a down)
# 169  0.036595  (red hot chili peppers, system of a down)
#
# [170 rows x 2 columns]
# Максимальная длина набора: 2

# %%
rules_de = ml.association_rules(freq_de, metric = "confidence", min_threshold = 0.4)
rules_de
# Out:
#            antecedents         consequents  antecedent support  \
# 0         (beatsteaks)         (die Ärzte)            0.093079
# 1       (billy talent)         (die Ärzte)            0.105012
# 2         (bloc party)       (the killers)            0.085919
# 3    (die toten hosen)         (die Ärzte)            0.115354
# 4       (farin urlaub)         (die Ärzte)            0.080350
# 5          (green day)         (die Ärzte)            0.070804
# 6            (nirvana)         (die Ärzte)            0.093079
# 7   (system of a down)         (die Ärzte)            0.128878
# 8      (the offspring)         (die Ärzte)            0.077963
# 9    (subway to sally)        (in extremo)            0.075577
# 10        (in extremo)   (subway to sally)            0.068417
# 11              (koЯn)  (system of a down)            0.081146
# 12   (subway to sally)         (rammstein)            0.075577
# 13  (system of a down)         (rammstein)            0.128878
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.194909  0.042959    0.461538  2.367975  0.024818    1.495170
# 1             0.194909  0.045346    0.431818  2.215492  0.024878    1.416961
# 2             0.105012  0.035004    0.407407  3.879630  0.025981    1.510292
# 3             0.194909  0.065235    0.565517  2.901450  0.042751    1.852988
# 4             0.194909  0.049324    0.613861  3.149485  0.033663    2.084981
# 5             0.194909  0.035800    0.505618  2.594130  0.021999    1.628481
# 6             0.194909  0.041368    0.444444  2.280272  0.023226    1.449165
# 7             0.194909  0.056484    0.438272  2.248602  0.031364    1.433240
# 8             0.194909  0.037391    0.479592  2.460600  0.022195    1.547039
# 9             0.068417  0.035800    0.473684  6.923501  0.030629    1.770008
# 10            0.075577  0.035800    0.523256  6.923501  0.030629    1.939034
# 11            0.128878  0.035004    0.431373  3.347131  0.024546    1.531973
# 12            0.146380  0.035800    0.473684  3.235984  0.024737    1.621877
# 13            0.146380  0.053302    0.413580  2.825382  0.034436    1.455646

# %% [markdown]
# <h1>Алгоритм FPGrowth</h1>
